# %% [markdown]
# ## Question 1: Blog

# %% [markdown]
# Blog link: https://richardxie-nguyen.github.io/

# %%
home = 'home.PNG'
first_post = 'first.PNG'
classes_1 = 'class_1.PNG'
classes_2 = 'class_2.PNG'
model = 'models.PNG'
loss_1 = 'loss_1.PNG'
loss_2 = 'loss_2.PNG'
loss_prev = 'loss_prev.PNG'
loss_prev_2 = 'loss_prev_2.PNG'

from fastai.vision.all import *
im = Image.open(home)
im.to_thumb(785,926)
# Out:
# <PIL.Image.Image image mode=RGBA size=665x785>

# %%
im = Image.open(first_post)
im.to_thumb(683,707)
# Out:
# <PIL.Image.Image image mode=RGBA size=660x683>

# %%
im = Image.open(classes_1)
im.to_thumb(710,835)
# Out:
# <PIL.Image.Image image mode=RGBA size=604x710>

# %%
im = Image.open(classes_2)
im.to_thumb(668,861)
# Out:
# <PIL.Image.Image image mode=RGBA size=518x668>

# %%
im = Image.open(model)
im.to_thumb(1250,522)
# Out:
# <PIL.Image.Image image mode=RGBA size=522x222>

# %%
im = Image.open(loss_1)
im.to_thumb(1040,1796)
# Out:
# <PIL.Image.Image image mode=RGBA size=520x898>

# %%
im = Image.open(loss_2)
im.to_thumb(522,460)
# Out:
# <PIL.Image.Image image mode=RGBA size=460x405>

# %% [markdown]
# The math functions could not be displayed on the website for some reason. Instead, they are displayed below in the repository previews.

# %%
im = Image.open(loss_prev)
im.to_thumb(3066,765)
# Out:
# <PIL.Image.Image image mode=RGBA size=765x191>

# %%
im = Image.open(loss_prev_2)
im.to_thumb(3048,693)
# Out:
# <PIL.Image.Image image mode=RGBA size=693x158>
